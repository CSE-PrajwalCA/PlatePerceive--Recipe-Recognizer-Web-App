# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Paths to your dataset
train_path = r"C:\Users\acess\OneDrive\Documents\Python Projects\Recipe_miniproject\splitted_data\train"
val_path = r"C:\Users\acess\OneDrive\Documents\Python Projects\Recipe_miniproject\splitted_data\val"
test_path = r"C:\Users\acess\OneDrive\Documents\Python Projects\Recipe_miniproject\splitted_data\test"

# Parameters
img_size = (224, 224)
batch_size = 32
num_classes = len(tf.io.gfile.listdir(train_path))  # Calculate number of classes dynamically

# Image data generators with robust augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Create generators
train_gen = train_datagen.flow_from_directory(
    train_path, 
    target_size=img_size, 
    batch_size=batch_size, 
    class_mode='categorical'
)

val_gen = val_datagen.flow_from_directory(
    val_path, 
    target_size=img_size, 
    batch_size=batch_size, 
    class_mode='categorical'
)

test_gen = test_datagen.flow_from_directory(
    test_path, 
    target_size=img_size, 
    batch_size=batch_size, 
    class_mode='categorical'
)

# Load VGG16 base model with pretrained weights
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Unfreeze the last few layers of the base model for fine-tuning
for layer in base_model.layers[:-4]:
    layer.trainable = False
for layer in base_model.layers[-4:]:
    layer.trainable = True

# Add custom layers
x = Flatten()(base_model.output)
x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = Dropout(0.5)(x)
output = Dense(num_classes, activation='softmax')(x)

# Define final model
model = Model(inputs=base_model.input, outputs=output)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks for training
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6),
    ModelCheckpoint(filepath="best_model.keras", monitor='val_accuracy', save_best_only=True)  # Updated extension
]

# Model summary
model.summary()

# Training the model
epochs = 50
history = model.fit(
    train_gen,
    epochs=epochs,
    validation_data=val_gen,
    callbacks=callbacks
)

# Save the final model
model.save("saved_models/vgg16_recipe_recognizer_final.keras")  # Updated extension

# Evaluate the model on test data
test_loss, test_acc = model.evaluate(test_gen)
print(f"Test Accuracy: {test_acc * 100:.2f}%")

# Visualize training history
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Found 693 images belonging to 14 classes.
# Found 195 images belonging to 14 classes.
# Found 113 images belonging to 14 classes.
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 512)            │    12,845,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 14)             │         3,598 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,695,182 (105.65 MB)
#  Trainable params: 20,059,918 (76.52 MB)
#  Non-trainable params: 7,635,264 (29.13 MB)
# Epoch 1/50
# c:\Users\acess\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.0861 - loss: 15.8874 - val_accuracy: 0.2154 - val_loss: 13.9030 - learning_rate: 1.0000e-04
# Epoch 2/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - accuracy: 0.1244 - loss: 13.4922 - val_accuracy: 0.2718 - val_loss: 11.9401 - learning_rate: 1.0000e-04
# Epoch 3/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - accuracy: 0.1648 - loss: 11.6912 - val_accuracy: 0.4410 - val_loss: 10.4083 - learning_rate: 1.0000e-04
# Epoch 4/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - accuracy: 0.2907 - loss: 10.3590 - val_accuracy: 0.5385 - val_loss: 9.1205 - learning_rate: 1.0000e-04
# Epoch 5/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - accuracy: 0.3950 - loss: 9.2966 - val_accuracy: 0.5487 - val_loss: 8.3157 - learning_rate: 1.0000e-04
# Epoch 6/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - accuracy: 0.4495 - loss: 8.4073 - val_accuracy: 0.6154 - val_loss: 7.5956 - learning_rate: 1.0000e-04
# Epoch 7/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - accuracy: 0.5442 - loss: 7.6918 - val_accuracy: 0.6974 - val_loss: 7.1089 - learning_rate: 1.0000e-04
# Epoch 8/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.5766 - loss: 7.1922 - val_accuracy: 0.6923 - val_loss: 6.7436 - learning_rate: 1.0000e-04
# Epoch 9/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.6320 - loss: 6.7681 - val_accuracy: 0.6872 - val_loss: 6.5039 - learning_rate: 1.0000e-04
# Epoch 10/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.6742 - loss: 6.3122 - val_accuracy: 0.7487 - val_loss: 6.0776 - learning_rate: 1.0000e-04
# Epoch 11/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - accuracy: 0.7434 - loss: 5.9464 - val_accuracy: 0.7385 - val_loss: 6.0763 - learning_rate: 1.0000e-04
# Epoch 12/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.7408 - loss: 5.7417 - val_accuracy: 0.7795 - val_loss: 5.6920 - learning_rate: 1.0000e-04
# Epoch 13/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.7673 - loss: 5.5662 - val_accuracy: 0.7795 - val_loss: 5.5190 - learning_rate: 1.0000e-04
# Epoch 14/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.8009 - loss: 5.2181 - val_accuracy: 0.8154 - val_loss: 5.2110 - learning_rate: 1.0000e-04
# Epoch 15/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.7571 - loss: 5.1565 - val_accuracy: 0.7846 - val_loss: 5.1416 - learning_rate: 1.0000e-04
# Epoch 16/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.8454 - loss: 4.8500 - val_accuracy: 0.7846 - val_loss: 5.0896 - learning_rate: 1.0000e-04
# Epoch 17/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.8394 - loss: 4.6758 - val_accuracy: 0.8154 - val_loss: 4.9683 - learning_rate: 1.0000e-04
# Epoch 18/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.8766 - loss: 4.4880 - val_accuracy: 0.7538 - val_loss: 5.1874 - learning_rate: 1.0000e-04
# Epoch 19/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 92s 4s/step - accuracy: 0.8248 - loss: 4.5291 - val_accuracy: 0.7949 - val_loss: 4.7655 - learning_rate: 1.0000e-04
# Epoch 20/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 111s 4s/step - accuracy: 0.8971 - loss: 4.2245 - val_accuracy: 0.7949 - val_loss: 4.7062 - learning_rate: 1.0000e-04
# Epoch 21/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.8936 - loss: 4.1645 - val_accuracy: 0.8410 - val_loss: 4.4729 - learning_rate: 1.0000e-04
# Epoch 22/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.9051 - loss: 3.9588 - val_accuracy: 0.7641 - val_loss: 4.6946 - learning_rate: 1.0000e-04
# Epoch 23/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.9045 - loss: 3.9313 - val_accuracy: 0.8051 - val_loss: 4.5155 - learning_rate: 1.0000e-04
# Epoch 24/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.9150 - loss: 3.8037 - val_accuracy: 0.8359 - val_loss: 4.2820 - learning_rate: 1.0000e-04
# Epoch 25/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.9070 - loss: 3.6893 - val_accuracy: 0.8205 - val_loss: 4.2172 - learning_rate: 1.0000e-04
# Epoch 26/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.9346 - loss: 3.5697 - val_accuracy: 0.8410 - val_loss: 4.1377 - learning_rate: 1.0000e-04
# Epoch 27/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.9429 - loss: 3.4678 - val_accuracy: 0.8205 - val_loss: 4.0617 - learning_rate: 1.0000e-04
# Epoch 28/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.9634 - loss: 3.3129 - val_accuracy: 0.8205 - val_loss: 4.0672 - learning_rate: 1.0000e-04
# Epoch 29/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.9595 - loss: 3.2860 - val_accuracy: 0.7846 - val_loss: 4.0134 - learning_rate: 1.0000e-04
# Epoch 30/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.9453 - loss: 3.2513 - val_accuracy: 0.8154 - val_loss: 4.1959 - learning_rate: 1.0000e-04
# Epoch 31/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.9523 - loss: 3.1606 - val_accuracy: 0.8154 - val_loss: 3.8290 - learning_rate: 1.0000e-04
# Epoch 32/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.9475 - loss: 3.1903 - val_accuracy: 0.8359 - val_loss: 3.7940 - learning_rate: 1.0000e-04
# Epoch 33/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - accuracy: 0.9447 - loss: 3.0533 - val_accuracy: 0.8256 - val_loss: 3.7088 - learning_rate: 1.0000e-04
# Epoch 34/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 117s 5s/step - accuracy: 0.9702 - loss: 2.9431 - val_accuracy: 0.8615 - val_loss: 3.4510 - learning_rate: 1.0000e-04
# Epoch 35/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - accuracy: 0.9458 - loss: 2.9244 - val_accuracy: 0.8308 - val_loss: 3.4183 - learning_rate: 1.0000e-04
# Epoch 36/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - accuracy: 0.9347 - loss: 2.9139 - val_accuracy: 0.8256 - val_loss: 3.5709 - learning_rate: 1.0000e-04
# Epoch 37/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 72s 3s/step - accuracy: 0.9490 - loss: 2.8164 - val_accuracy: 0.8308 - val_loss: 3.4809 - learning_rate: 1.0000e-04
# Epoch 38/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.9504 - loss: 2.7660 - val_accuracy: 0.8359 - val_loss: 3.5169 - learning_rate: 1.0000e-04
# Epoch 39/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - accuracy: 0.9651 - loss: 2.6807 - val_accuracy: 0.8256 - val_loss: 3.4510 - learning_rate: 2.0000e-05
# Epoch 40/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 83s 4s/step - accuracy: 0.9832 - loss: 2.6144 - val_accuracy: 0.8103 - val_loss: 3.5982 - learning_rate: 2.0000e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.7548 - loss: 3.7636
# Test Accuracy: 76.99%

# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Paths to your dataset
train_path = r"C:\Users\acess\OneDrive\Documents\Python Projects\Recipe_miniproject\splitted_data\train"
val_path = r"C:\Users\acess\OneDrive\Documents\Python Projects\Recipe_miniproject\splitted_data\val"
test_path = r"C:\Users\acess\OneDrive\Documents\Python Projects\Recipe_miniproject\splitted_data\test"

# Parameters
img_size = (224, 224)
batch_size = 32
num_classes = len(tf.io.gfile.listdir(train_path))  # Calculate number of classes dynamically

# Load datasets using image_dataset_from_directory
train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_path,
    image_size=img_size,
    batch_size=batch_size,
    label_mode='categorical'
)

val_dataset = tf.keras.utils.image_dataset_from_directory(
    val_path,
    image_size=img_size,
    batch_size=batch_size,
    label_mode='categorical'
)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_path,
    image_size=img_size,
    batch_size=batch_size,
    label_mode='categorical'
)

# Normalize pixel values to [0, 1]
normalization_layer = tf.keras.layers.Rescaling(1./255)
train_dataset = train_dataset.map(lambda x, y: (normalization_layer(x), y))
val_dataset = val_dataset.map(lambda x, y: (normalization_layer(x), y))
test_dataset = test_dataset.map(lambda x, y: (normalization_layer(x), y))

# Apply data augmentation
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2),
])

train_dataset = train_dataset.map(lambda x, y: (data_augmentation(x, training=True), y))

# Optimize dataset for performance
AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
val_dataset = val_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# Load VGG16 base model with pretrained weights
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Unfreeze the last few layers of the base model for fine-tuning
for layer in base_model.layers[:-4]:
    layer.trainable = False
for layer in base_model.layers[-4:]:
    layer.trainable = True

# Add custom layers
x = Flatten()(base_model.output)
x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = Dropout(0.5)(x)
output = Dense(num_classes, activation='softmax')(x)

# Define final model
model = Model(inputs=base_model.input, outputs=output)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks for training
callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),  # Increase patience
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6),
    ModelCheckpoint(filepath="best_model.keras", monitor='val_accuracy', save_best_only=True)
]

# Model summary
model.summary()

# Model training
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=50,  # Specify maximum epochs
    callbacks=callbacks
)

# Model evaluation
test_loss, test_accuracy = model.evaluate(test_dataset)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# Save the final model
model.save("saved_models/vgg16_recipe_recognizer_final.keras")

# Visualize training history
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Found 693 files belonging to 14 classes.
# Found 195 files belonging to 14 classes.
# Found 113 files belonging to 14 classes.
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 512)            │    12,845,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 14)             │         3,598 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,695,182 (105.65 MB)
#  Trainable params: 20,059,918 (76.52 MB)
#  Non-trainable params: 7,635,264 (29.13 MB)
# Epoch 1/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - accuracy: 0.0910 - loss: 15.9778 - val_accuracy: 0.2308 - val_loss: 14.0136 - learning_rate: 1.0000e-04
# Epoch 2/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - accuracy: 0.1569 - loss: 13.6063 - val_accuracy: 0.4103 - val_loss: 12.0616 - learning_rate: 1.0000e-04
# Epoch 3/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 71s 3s/step - accuracy: 0.2777 - loss: 11.8359 - val_accuracy: 0.4974 - val_loss: 10.5257 - learning_rate: 1.0000e-04
# Epoch 4/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 72s 3s/step - accuracy: 0.3786 - loss: 10.4658 - val_accuracy: 0.5897 - val_loss: 9.4341 - learning_rate: 1.0000e-04
# Epoch 5/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.4805 - loss: 9.3704 - val_accuracy: 0.5897 - val_loss: 8.6014 - learning_rate: 1.0000e-04
# Epoch 6/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 78s 4s/step - accuracy: 0.5225 - loss: 8.5956 - val_accuracy: 0.6051 - val_loss: 7.9289 - learning_rate: 1.0000e-04
# Epoch 7/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.5897 - loss: 7.9272 - val_accuracy: 0.6718 - val_loss: 7.4392 - learning_rate: 1.0000e-04
# Epoch 8/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - accuracy: 0.6540 - loss: 7.3514 - val_accuracy: 0.7026 - val_loss: 6.9381 - learning_rate: 1.0000e-04
# Epoch 9/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 120s 3s/step - accuracy: 0.6635 - loss: 6.9908 - val_accuracy: 0.7282 - val_loss: 6.5817 - learning_rate: 1.0000e-04
# Epoch 10/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 71s 3s/step - accuracy: 0.7185 - loss: 6.5341 - val_accuracy: 0.7179 - val_loss: 6.3740 - learning_rate: 1.0000e-04
# Epoch 11/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 72s 3s/step - accuracy: 0.8010 - loss: 6.0837 - val_accuracy: 0.7333 - val_loss: 6.2055 - learning_rate: 1.0000e-04
# Epoch 12/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 73s 3s/step - accuracy: 0.7934 - loss: 5.8968 - val_accuracy: 0.7641 - val_loss: 5.8630 - learning_rate: 1.0000e-04
# Epoch 13/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.8402 - loss: 5.5714 - val_accuracy: 0.7538 - val_loss: 5.7369 - learning_rate: 1.0000e-04
# Epoch 14/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 79s 4s/step - accuracy: 0.8026 - loss: 5.4012 - val_accuracy: 0.7538 - val_loss: 5.6352 - learning_rate: 1.0000e-04
# Epoch 15/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.8822 - loss: 5.0193 - val_accuracy: 0.7846 - val_loss: 5.4512 - learning_rate: 1.0000e-04
# Epoch 16/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - accuracy: 0.8214 - loss: 5.0749 - val_accuracy: 0.8000 - val_loss: 5.1322 - learning_rate: 1.0000e-04
# Epoch 17/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 118s 3s/step - accuracy: 0.8744 - loss: 4.7369 - val_accuracy: 0.7897 - val_loss: 4.9978 - learning_rate: 1.0000e-04
# Epoch 18/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 70s 3s/step - accuracy: 0.8573 - loss: 4.6717 - val_accuracy: 0.7846 - val_loss: 4.9861 - learning_rate: 1.0000e-04
# Epoch 19/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 71s 3s/step - accuracy: 0.8963 - loss: 4.3988 - val_accuracy: 0.7641 - val_loss: 4.8965 - learning_rate: 1.0000e-04
# Epoch 20/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 72s 3s/step - accuracy: 0.8869 - loss: 4.3409 - val_accuracy: 0.7128 - val_loss: 5.0446 - learning_rate: 1.0000e-04
# Epoch 21/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.9288 - loss: 4.1299 - val_accuracy: 0.7282 - val_loss: 4.8781 - learning_rate: 1.0000e-04
# Epoch 22/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 79s 4s/step - accuracy: 0.8774 - loss: 4.1753 - val_accuracy: 0.7487 - val_loss: 4.7986 - learning_rate: 1.0000e-04
# Epoch 23/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.9248 - loss: 3.9751 - val_accuracy: 0.7846 - val_loss: 4.4416 - learning_rate: 1.0000e-04
# Epoch 24/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - accuracy: 0.9331 - loss: 3.8222 - val_accuracy: 0.8051 - val_loss: 4.2218 - learning_rate: 1.0000e-04
# Epoch 25/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - accuracy: 0.9513 - loss: 3.6890 - val_accuracy: 0.7179 - val_loss: 4.5774 - learning_rate: 1.0000e-04
# Epoch 26/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - accuracy: 0.9303 - loss: 3.7010 - val_accuracy: 0.7744 - val_loss: 4.1256 - learning_rate: 1.0000e-04
# Epoch 27/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - accuracy: 0.9574 - loss: 3.4742 - val_accuracy: 0.8154 - val_loss: 4.0495 - learning_rate: 1.0000e-04
# Epoch 28/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 120s 3s/step - accuracy: 0.9321 - loss: 3.4439 - val_accuracy: 0.8103 - val_loss: 3.9935 - learning_rate: 1.0000e-04
# Epoch 29/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 70s 3s/step - accuracy: 0.9484 - loss: 3.3298 - val_accuracy: 0.7744 - val_loss: 4.1950 - learning_rate: 1.0000e-04
# Epoch 30/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 71s 3s/step - accuracy: 0.9582 - loss: 3.2145 - val_accuracy: 0.7897 - val_loss: 3.8475 - learning_rate: 1.0000e-04
# Epoch 31/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 72s 3s/step - accuracy: 0.9538 - loss: 3.1733 - val_accuracy: 0.7846 - val_loss: 3.8073 - learning_rate: 1.0000e-04
# Epoch 32/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 81s 4s/step - accuracy: 0.9415 - loss: 3.1299 - val_accuracy: 0.7795 - val_loss: 3.8303 - learning_rate: 1.0000e-04
# Epoch 33/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 80s 4s/step - accuracy: 0.9168 - loss: 3.1318 - val_accuracy: 0.7897 - val_loss: 3.7788 - learning_rate: 1.0000e-04
# Epoch 34/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.9605 - loss: 2.9432 - val_accuracy: 0.7897 - val_loss: 3.6099 - learning_rate: 1.0000e-04
# Epoch 35/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - accuracy: 0.9605 - loss: 2.9094 - val_accuracy: 0.7949 - val_loss: 3.5712 - learning_rate: 1.0000e-04
# Epoch 36/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.9788 - loss: 2.8100 - val_accuracy: 0.8000 - val_loss: 3.4836 - learning_rate: 1.0000e-04
# Epoch 37/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - accuracy: 0.9566 - loss: 2.7843 - val_accuracy: 0.7897 - val_loss: 3.4395 - learning_rate: 1.0000e-04
# Epoch 38/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.9689 - loss: 2.6910 - val_accuracy: 0.7692 - val_loss: 3.6011 - learning_rate: 1.0000e-04
# Epoch 39/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.9734 - loss: 2.6360 - val_accuracy: 0.8000 - val_loss: 3.4596 - learning_rate: 1.0000e-04
# Epoch 40/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - accuracy: 0.9782 - loss: 2.5782 - val_accuracy: 0.8051 - val_loss: 3.3179 - learning_rate: 1.0000e-04
# Epoch 41/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.9754 - loss: 2.4920 - val_accuracy: 0.7949 - val_loss: 3.4297 - learning_rate: 1.0000e-04
# Epoch 42/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - accuracy: 0.9727 - loss: 2.4542 - val_accuracy: 0.7692 - val_loss: 3.7129 - learning_rate: 1.0000e-04
# Epoch 43/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - accuracy: 0.9835 - loss: 2.3907 - val_accuracy: 0.8256 - val_loss: 3.1907 - learning_rate: 1.0000e-04
# Epoch 44/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - accuracy: 0.9831 - loss: 2.3330 - val_accuracy: 0.8308 - val_loss: 3.2787 - learning_rate: 1.0000e-04
# Epoch 45/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - accuracy: 0.9655 - loss: 2.3546 - val_accuracy: 0.7949 - val_loss: 3.0981 - learning_rate: 1.0000e-04
# Epoch 46/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - accuracy: 0.9838 - loss: 2.2457 - val_accuracy: 0.8205 - val_loss: 2.9736 - learning_rate: 1.0000e-04
# Epoch 47/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.9925 - loss: 2.1874 - val_accuracy: 0.8051 - val_loss: 3.0666 - learning_rate: 1.0000e-04
# Epoch 48/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.9673 - loss: 2.2055 - val_accuracy: 0.8308 - val_loss: 3.0765 - learning_rate: 1.0000e-04
# Epoch 49/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.9754 - loss: 2.1552 - val_accuracy: 0.7897 - val_loss: 2.9513 - learning_rate: 1.0000e-04
# Epoch 50/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - accuracy: 0.9773 - loss: 2.1266 - val_accuracy: 0.8410 - val_loss: 2.5922 - learning_rate: 1.0000e-04
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.7405 - loss: 2.9341
# Test Accuracy: 75.22%

# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras.applications import VGG19  # Updated to VGG19
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Paths to your dataset
train_path = r"C:\Users\acess\OneDrive\Documents\Python Projects\Recipe_miniproject\splitted_data\train"
val_path = r"C:\Users\acess\OneDrive\Documents\Python Projects\Recipe_miniproject\splitted_data\val"
test_path = r"C:\Users\acess\OneDrive\Documents\Python Projects\Recipe_miniproject\splitted_data\test"

# Parameters
img_size = (224, 224)
batch_size = 32
num_classes = len(tf.io.gfile.listdir(train_path))  # Calculate number of classes dynamically

# Load datasets using image_dataset_from_directory
train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_path,
    image_size=img_size,
    batch_size=batch_size,
    label_mode='categorical'
)

val_dataset = tf.keras.utils.image_dataset_from_directory(
    val_path,
    image_size=img_size,
    batch_size=batch_size,
    label_mode='categorical'
)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_path,
    image_size=img_size,
    batch_size=batch_size,
    label_mode='categorical'
)

# Normalize pixel values to [0, 1]
normalization_layer = tf.keras.layers.Rescaling(1./255)
train_dataset = train_dataset.map(lambda x, y: (normalization_layer(x), y))
val_dataset = val_dataset.map(lambda x, y: (normalization_layer(x), y))
test_dataset = test_dataset.map(lambda x, y: (normalization_layer(x), y))

# Apply data augmentation
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2),
])

train_dataset = train_dataset.map(lambda x, y: (data_augmentation(x, training=True), y))

# Optimize dataset for performance
AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
val_dataset = val_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# Load VGG19 base model with pretrained weights
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))  # Updated to VGG19

# Unfreeze the last few layers of the base model for fine-tuning
for layer in base_model.layers[:-4]:
    layer.trainable = False
for layer in base_model.layers[-4:]:
    layer.trainable = True

# Add custom layers
x = Flatten()(base_model.output)
x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = Dropout(0.5)(x)
output = Dense(num_classes, activation='softmax')(x)

# Define final model
model = Model(inputs=base_model.input, outputs=output)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks for training
callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),  # Increased patience
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6),
    ModelCheckpoint(filepath="best_model.keras", monitor='val_accuracy', save_best_only=True)
]

# Model summary
model.summary()

# Model training
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=50,  # Specify maximum epochs
    callbacks=callbacks
)

# Model evaluation
test_loss, test_accuracy = model.evaluate(test_dataset)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# Save the final model
model.save("saved_models/vgg19_recipe_recognizer_final.keras")

# Visualize training history
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Found 693 files belonging to 14 classes.
# Found 195 files belonging to 14 classes.
# Found 113 files belonging to 14 classes.
# Model: "functional_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_14 (InputLayer)     │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv4 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 512)            │    12,845,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 14)             │         3,598 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,004,878 (125.90 MB)
#  Trainable params: 20,059,918 (76.52 MB)
#  Non-trainable params: 12,944,960 (49.38 MB)
# Epoch 1/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 102s 5s/step - accuracy: 0.0750 - loss: 15.9542 - val_accuracy: 0.1897 - val_loss: 13.8870 - learning_rate: 1.0000e-04
# Epoch 2/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 106s 5s/step - accuracy: 0.1431 - loss: 13.4772 - val_accuracy: 0.2974 - val_loss: 11.8909 - learning_rate: 1.0000e-04
# Epoch 3/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 108s 5s/step - accuracy: 0.2397 - loss: 11.6407 - val_accuracy: 0.4359 - val_loss: 10.2734 - learning_rate: 1.0000e-04
# Epoch 4/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 110s 5s/step - accuracy: 0.3527 - loss: 10.1647 - val_accuracy: 0.5641 - val_loss: 9.0920 - learning_rate: 1.0000e-04
# Epoch 5/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 107s 5s/step - accuracy: 0.4115 - loss: 9.0922 - val_accuracy: 0.5641 - val_loss: 8.2265 - learning_rate: 1.0000e-04
# Epoch 6/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 137s 5s/step - accuracy: 0.5000 - loss: 8.2003 - val_accuracy: 0.6308 - val_loss: 7.6080 - learning_rate: 1.0000e-04
# Epoch 7/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 108s 5s/step - accuracy: 0.5405 - loss: 7.6022 - val_accuracy: 0.6256 - val_loss: 7.2227 - learning_rate: 1.0000e-04
# Epoch 8/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 107s 5s/step - accuracy: 0.5763 - loss: 7.0293 - val_accuracy: 0.6256 - val_loss: 6.7093 - learning_rate: 1.0000e-04
# Epoch 9/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 108s 5s/step - accuracy: 0.6459 - loss: 6.6649 - val_accuracy: 0.6513 - val_loss: 6.3021 - learning_rate: 1.0000e-04
# Epoch 10/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 138s 5s/step - accuracy: 0.6618 - loss: 6.2238 - val_accuracy: 0.6872 - val_loss: 5.9698 - learning_rate: 1.0000e-04
# Epoch 11/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 109s 5s/step - accuracy: 0.7286 - loss: 5.8089 - val_accuracy: 0.7026 - val_loss: 5.7612 - learning_rate: 1.0000e-04
# Epoch 12/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 109s 5s/step - accuracy: 0.7124 - loss: 5.5898 - val_accuracy: 0.7333 - val_loss: 5.4211 - learning_rate: 1.0000e-04
# Epoch 13/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 108s 5s/step - accuracy: 0.7688 - loss: 5.2393 - val_accuracy: 0.7231 - val_loss: 5.3289 - learning_rate: 1.0000e-04
# Epoch 14/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 108s 5s/step - accuracy: 0.7930 - loss: 4.9836 - val_accuracy: 0.6872 - val_loss: 5.1589 - learning_rate: 1.0000e-04
# Epoch 15/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 109s 5s/step - accuracy: 0.8235 - loss: 4.7606 - val_accuracy: 0.7590 - val_loss: 4.8787 - learning_rate: 1.0000e-04
# Epoch 16/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 111s 5s/step - accuracy: 0.8452 - loss: 4.5751 - val_accuracy: 0.7077 - val_loss: 4.8473 - learning_rate: 1.0000e-04
# Epoch 17/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 133s 5s/step - accuracy: 0.8518 - loss: 4.3855 - val_accuracy: 0.7231 - val_loss: 4.9177 - learning_rate: 1.0000e-04
# Epoch 18/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 115s 5s/step - accuracy: 0.8393 - loss: 4.3398 - val_accuracy: 0.7538 - val_loss: 4.5519 - learning_rate: 1.0000e-04
# Epoch 19/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 100s 5s/step - accuracy: 0.8718 - loss: 4.1233 - val_accuracy: 0.7282 - val_loss: 4.5361 - learning_rate: 1.0000e-04
# Epoch 20/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - accuracy: 0.8805 - loss: 4.0013 - val_accuracy: 0.7436 - val_loss: 4.7966 - learning_rate: 1.0000e-04
# Epoch 21/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8624 - loss: 3.9271 - val_accuracy: 0.7538 - val_loss: 4.2870 - learning_rate: 1.0000e-04
# Epoch 22/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 105s 5s/step - accuracy: 0.9000 - loss: 3.7006 - val_accuracy: 0.7077 - val_loss: 4.3608 - learning_rate: 1.0000e-04
# Epoch 23/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 109s 5s/step - accuracy: 0.8918 - loss: 3.6341 - val_accuracy: 0.7590 - val_loss: 4.0947 - learning_rate: 1.0000e-04
# Epoch 24/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 109s 5s/step - accuracy: 0.9217 - loss: 3.4986 - val_accuracy: 0.7949 - val_loss: 4.0385 - learning_rate: 1.0000e-04
# Epoch 25/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 109s 5s/step - accuracy: 0.9349 - loss: 3.3371 - val_accuracy: 0.7744 - val_loss: 3.9663 - learning_rate: 1.0000e-04
# Epoch 26/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 108s 5s/step - accuracy: 0.9383 - loss: 3.2526 - val_accuracy: 0.7795 - val_loss: 4.0561 - learning_rate: 1.0000e-04
# Epoch 27/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 108s 5s/step - accuracy: 0.9090 - loss: 3.2858 - val_accuracy: 0.7590 - val_loss: 4.0730 - learning_rate: 1.0000e-04
# Epoch 28/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 108s 5s/step - accuracy: 0.9303 - loss: 3.1196 - val_accuracy: 0.7897 - val_loss: 3.7235 - learning_rate: 1.0000e-04
# Epoch 29/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 109s 5s/step - accuracy: 0.9303 - loss: 3.0638 - val_accuracy: 0.7333 - val_loss: 4.0411 - learning_rate: 1.0000e-04
# Epoch 30/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 109s 5s/step - accuracy: 0.9056 - loss: 3.0462 - val_accuracy: 0.7538 - val_loss: 3.6631 - learning_rate: 1.0000e-04
# Epoch 31/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 109s 5s/step - accuracy: 0.9189 - loss: 2.9371 - val_accuracy: 0.7538 - val_loss: 3.8563 - learning_rate: 1.0000e-04
# Epoch 32/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 108s 5s/step - accuracy: 0.9367 - loss: 2.8864 - val_accuracy: 0.7795 - val_loss: 3.5257 - learning_rate: 1.0000e-04
# Epoch 33/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 108s 5s/step - accuracy: 0.9526 - loss: 2.7436 - val_accuracy: 0.7744 - val_loss: 3.5492 - learning_rate: 1.0000e-04
# Epoch 34/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 118s 4s/step - accuracy: 0.9554 - loss: 2.6836 - val_accuracy: 0.7538 - val_loss: 3.7456 - learning_rate: 1.0000e-04
# Epoch 35/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 89s 4s/step - accuracy: 0.9395 - loss: 2.6708 - val_accuracy: 0.7692 - val_loss: 3.3776 - learning_rate: 1.0000e-04
# Epoch 36/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 90s 4s/step - accuracy: 0.9672 - loss: 2.5514 - val_accuracy: 0.7590 - val_loss: 3.5456 - learning_rate: 1.0000e-04
# Epoch 37/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 92s 4s/step - accuracy: 0.9651 - loss: 2.4993 - val_accuracy: 0.7949 - val_loss: 3.3243 - learning_rate: 1.0000e-04
# Epoch 38/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 101s 5s/step - accuracy: 0.9595 - loss: 2.4495 - val_accuracy: 0.8154 - val_loss: 3.1450 - learning_rate: 1.0000e-04
# Epoch 39/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 109s 5s/step - accuracy: 0.9603 - loss: 2.3846 - val_accuracy: 0.7846 - val_loss: 3.2414 - learning_rate: 1.0000e-04
# Epoch 40/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 108s 5s/step - accuracy: 0.9408 - loss: 2.3938 - val_accuracy: 0.7333 - val_loss: 3.4145 - learning_rate: 1.0000e-04
# Epoch 41/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 108s 5s/step - accuracy: 0.9625 - loss: 2.3348 - val_accuracy: 0.7641 - val_loss: 3.2975 - learning_rate: 1.0000e-04
# Epoch 42/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 108s 5s/step - accuracy: 0.9664 - loss: 2.2359 - val_accuracy: 0.7744 - val_loss: 3.3931 - learning_rate: 1.0000e-04
# Epoch 43/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 109s 5s/step - accuracy: 0.9716 - loss: 2.2077 - val_accuracy: 0.8205 - val_loss: 2.9494 - learning_rate: 1.0000e-04
# Epoch 44/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 109s 5s/step - accuracy: 0.9574 - loss: 2.2114 - val_accuracy: 0.7333 - val_loss: 3.3474 - learning_rate: 1.0000e-04
# Epoch 45/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 109s 5s/step - accuracy: 0.9602 - loss: 2.1632 - val_accuracy: 0.7590 - val_loss: 3.0757 - learning_rate: 1.0000e-04
# Epoch 46/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 108s 5s/step - accuracy: 0.9632 - loss: 2.0772 - val_accuracy: 0.7436 - val_loss: 2.9944 - learning_rate: 1.0000e-04
# Epoch 47/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 109s 5s/step - accuracy: 0.9591 - loss: 2.0609 - val_accuracy: 0.7795 - val_loss: 3.0558 - learning_rate: 1.0000e-04
# Epoch 48/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 109s 5s/step - accuracy: 0.9655 - loss: 1.9950 - val_accuracy: 0.8000 - val_loss: 2.9593 - learning_rate: 1.0000e-04
# Epoch 49/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 107s 5s/step - accuracy: 0.9784 - loss: 1.9460 - val_accuracy: 0.7949 - val_loss: 2.9864 - learning_rate: 2.0000e-05
# Epoch 50/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 108s 5s/step - accuracy: 0.9824 - loss: 1.9412 - val_accuracy: 0.8000 - val_loss: 2.9663 - learning_rate: 2.0000e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.7171 - loss: 3.4421
# Test Accuracy: 74.34%
